# %% [markdown]
# # Certifying ACLs and Firewall Rules

# %%
# Import packages and load questions
import pandas as pd
from IPython.display import display
from pandas.io.formats.style import Styler

from pybatfish.client.commands import *
from pybatfish.datamodel.answer import TableAnswer
from pybatfish.question import bfq, load_questions
from pybatfish.util import get_html
import logging

logging.getLogger('pybatfish').setLevel(logging.WARN)
load_questions()

# %%
# helper code to nicely print pandas frames
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_columns', None)
# Prevent rendering text between '$' as MathJax expressions
pd.set_option('display.html.use_mathjax', False)

# UUID for CSS styles used by pandas styler.
# Keeps our notebook HTML deterministic when displaying dataframes
_STYLE_UUID = "pybfstyle"

class MyStyler(Styler):
    """A custom styler for displaying DataFrames in HTML"""

    def __repr__(self):
        return repr(self.data)

def show(df):
    """
    Displays a dataframe as HTML table.
    Replaces newlines and double-spaces in the input with HTML markup, and
    left-aligns the text.
    """
    if isinstance(df, TableAnswer):
        df = df.frame()

    # workaround for Pandas bug in Python 2.7 for empty frames
    if not isinstance(df, pd.DataFrame) or df.size == 0:
        display(df)
        return
    display(MyStyler(df).set_uuid(_STYLE_UUID).format(get_html)
            .set_properties(**{'text-align': 'left', 'vertical-align': 'top'}))

# %%
def make_acl(reference_flows, hostname, filter_name):
    """
    Turns the list of reference flows into an NXOS config file with the provided hostname and filter_name.
    """
    acl_lines = ["hostname {}".format(hostname), 
                 "ip access-list {}".format(filter_name)]
    seq_number = 10
    for flow in reference_flows:
        acl_lines.append("  {} {}".format(seq_number, flow))
        seq_number += 10
    acl_lines.append("  {} deny ip any any".format(seq_number))
    return "\n".join(acl_lines)

# %%
# initialize the snapshot we want to analyze
bf_session.init_snapshot("example/snapshot/", name="snapshot", overwrite=True)

# define the reference set flows that our ACL should allow
reference_flows = [
"permit ip 11.36.216.170/32 11.36.216.169/32",
"permit ip 11.36.216.176/32 11.36.216.179/32",
"permit ip 204.150.33.175/32 204.150.33.83/32",
"permit ip 205.248.59.64/32 205.248.59.67/32",
]

# turns the reference flows into a snapshot
# the hostname and filtername should correspond to the entities we want to evaluate
# we use Cisco-NXOS as the format for the reference ACL---the ACL int he snapshot can be in any format
nxos_acl = make_acl(reference_flows, "rtr-with-acl", "acl_in")
bf_session.init_snapshot_from_text(nxos_acl, platform="cisco-nx", snapshot_name="reference", overwrite=True)
# Out:
# 'reference'

# %%
# Now, compare the two ACLs in the two snapshots
answer = bfq.compareFilters().answer(snapshot="snapshot", reference_snapshot="reference")
show(answer.frame())
# Out:
#             Node Filter_Name Line_Index  \
# 0   rtr-with-acl  acl_in      0
# 1   rtr-with-acl  acl_in      1
# 2   rtr-with-acl  acl_in      6
# 3   rtr-with-acl  acl_in      7
# 4   rtr-with-acl  acl_in      8
# 5   rtr-with-acl  acl_in      9
# 6   rtr-with-acl  acl_in      10
# 7   rtr-with-acl  acl_in      11
# 8   rtr-with-acl  acl_in      12
# 9   rtr-with-acl  acl_in      13
# 10  rtr-with-acl  acl_in      14
# 11  rtr-with-acl  acl_in      15
# 12  rtr-with-acl  acl_in      16
# 13  rtr-with-acl  acl_in      17
# 14  rtr-with-acl  acl_in      18
# 15  rtr-with-acl  acl_in      19
# 16  rtr-with-acl  acl_in      20
# 17  rtr-with-acl  acl_in      29
# 18  rtr-with-acl  acl_in      29
# 19  rtr-with-acl  acl_in      31
# 20  rtr-with-acl  acl_in      65
# 21  rtr-with-acl  acl_in      66
# 22  rtr-with-acl  acl_in      100
# 23  rtr-with-acl  acl_in      100
#
#                                                                  Line_Content  \
# 0   50 permit udp 117.186.185.0/24 range 49152 65535 117.186.185.0/24 eq 3784
# 1   60 permit udp 117.186.185.0/24 range 49152 65535 117.186.185.0/24 eq 3785
# 2   160 permit tcp 205.248.58.190/32 205.248.58.188/32 eq bgp
# 3   180 permit tcp 205.248.57.174/32 205.248.57.173/32 eq bgp
# 4   200 permit tcp 11.36.202.137/32 11.36.202.139/32 eq bgp
# 5   220 permit tcp 11.36.202.142/32 11.36.202.141/32 eq bgp
# 6   240 permit tcp 2.73.168.211/32 2.73.168.208/32 eq bgp
# 7   260 permit tcp 212.58.171.208/32 212.58.171.208/32 eq bgp
# 8   280 permit tcp 112.104.108.152/32 112.104.108.154/32 eq bgp
# 9   300 permit tcp 218.8.104.14/32 218.8.104.15/32 eq bgp
# 10  320 permit tcp 218.8.104.0/32 218.8.104.1/32 eq bgp
# 11  340 permit tcp 218.8.104.62/32 218.8.104.63/32 eq bgp
# 12  360 permit tcp 218.8.104.59/32 218.8.104.58/32 eq bgp
# 13  380 permit icmp 218.8.104.14/32 218.8.104.15/32 echo-reply
# 14  400 permit icmp 218.8.104.0/32 218.8.104.1/32 echo-reply
# 15  420 permit icmp 218.8.104.62/32 218.8.104.63/32 echo-reply
# 16  440 permit icmp 218.8.104.59/32 218.8.104.58/32 echo-reply
# 17  620 deny ip 11.36.192.0/19 any
# 18  620 deny ip 11.36.192.0/19 any
# 19  660 permit udp 10.10.10.0/24 218.8.104.58/32 eq domain
# 20  1300 permit icmp any any echo-reply
# 21  1340 permit icmp any any ttl-exceeded
# 22  2080 deny ip any any
# 23  2080 deny ip any any
#
#    Line_Action Reference_Line_Index  \
# 0   PERMIT      4
# 1   PERMIT      4
# 2   PERMIT      4
# 3   PERMIT      4
# 4   PERMIT      4
# 5   PERMIT      4
# 6   PERMIT      4
# 7   PERMIT      4
# 8   PERMIT      4
# 9   PERMIT      4
# 10  PERMIT      4
# 11  PERMIT      4
# 12  PERMIT      4
# 13  PERMIT      4
# 14  PERMIT      4
# 15  PERMIT      4
# 16  PERMIT      4
# 17  DENY        0
# 18  DENY        1
# 19  PERMIT      4
# 20  PERMIT      4
# 21  PERMIT      4
# 22  DENY        2
# 23  DENY        3
#
#                              Reference_Line_Content
# 0   50 deny ip any any
# 1   50 deny ip any any
# 2   50 deny ip any any
# 3   50 deny ip any any
# 4   50 deny ip any any
# 5   50 deny ip any any
# 6   50 deny ip any any
# 7   50 deny ip any any
# 8   50 deny ip any any
# 9   50 deny ip any any
# 10  50 deny ip any any
# 11  50 deny ip any any
# 12  50 deny ip any any
# 13  50 deny ip any any
# 14  50 deny ip any any
# 15  50 deny ip any any
# 16  50 deny ip any any
# 17  10 permit ip 11.36.216.170/32 11.36.216.169/32
# 18  20 permit ip 11.36.216.176/32 11.36.216.179/32
# 19  50 deny ip any any
# 20  50 deny ip any any
# 21  50 deny ip any any
# 22  30 permit ip 204.150.33.175/32 204.150.33.83/32
# 23  40 permit ip 205.248.59.64/32 205.248.59.67/32
